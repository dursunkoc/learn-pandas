# %%
import pandas as pd

# %%
movies = pd.read_csv(filepath_or_buffer='http://bit.ly/imdbratings')

# %%
movies.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
movies_title_genre = pd.read_csv(filepath_or_buffer='http://bit.ly/imdbratings', usecols=['title','genre'])

# %%
movies_title_genre.columns = ['t','g']

# %%
movies_title_genre.columns
# Out:
# Index(['t', 'g'], dtype='object')

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
import numpy as np
movies.select_dtypes(np.number)
# Out:
#      star_rating  duration
# 0            9.3       142
# 1            9.2       175
# 2            9.1       200
# 3            9.0       152
# 4            8.9       154
# 5            8.9        96
# 6            8.9       161
# 7            8.9       201
# 8            8.9       195
# 9            8.9       139
# 10           8.8       178
# 11           8.8       148
# 12           8.8       124
# 13           8.8       142
# 14           8.8       179
# 15           8.7       169
# 16           8.7       133
# 17           8.7       207
# 18           8.7       146
# 19           8.7       121
# 20           8.7       136
# 21           8.7       130
# 22           8.7       130
# 23           8.7       106
# 24           8.7       127
# 25           8.6       116
# 26           8.6       175
# 27           8.6       118
# 28           8.6       110
# 29           8.6        87
# ..           ...       ...
# 949          7.4       103
# 950          7.4       108
# ...
